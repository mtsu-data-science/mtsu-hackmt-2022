# %% [markdown]
# <a href="https://colab.research.google.com/github/mtsu-data-science/mtsu-hackmt-2022/blob/main/data_viz_notebooks/sample_data_viz_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
# This url is a shared link to a sample dataset
# stored in the HackMT - source_data/ directory
url = "https://drive.google.com/file/d/1sRW0DKZ0S789uIid4e9XhTb4DmRu5uJB/view?usp=sharing"

# This gets the file id from the shared url
url_file_id = url.split("/")[-2]

# This prepares the URL so pandas can read the csv file
url_for_pandas = f"https://drive.google.com/uc?id={url_file_id}"

# Passing the URL into 
df = pd.read_csv(url_for_pandas, index_col=0)

# %%
df.head()
# Out:
#        id                        title  ... vote_count  video
# 0   19404  Dilwale Dulhania Le Jayenge  ...       3304  False
# 1     278     The Shawshank Redemption  ...      20369  False
# 2     238                The Godfather  ...      15219  False
# 3  724089    Gabriel's Inferno Part II  ...       1360  False
# 4     424             Schindler's List  ...      12158  False
#
# [5 rows x 8 columns]
